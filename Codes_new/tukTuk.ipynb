# %%
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
import math
import pandas as pd

# %%
df=pd.read_csv(r"D:\T\test_codeEVT\dataset\Majestic.csv")
df=df[['Track ID','TimeStamp','Type','X','Y']].dropna()
df['Track ID'] = df['Track ID'].astype(int)
df=df[df['Track ID']>=1]
df['Track ID'] = df['Track ID'].sort_values()
unique_tracks_per_type = df.groupby('Type')['Track ID'].nunique()
print(unique_tracks_per_type)
print(f'total {sum(unique_tracks_per_type)}')
print(df['TimeStamp'].max())
# Out:
# Type
# Bicycle           1
# Bus              61
# Car            1040
# Light Truck     203
# Motorcycle     3011
# Pedestrian     1069
# Tractor           1
# Tuk-Tuk        1740
# Van               9
# Name: Track ID, dtype: int64
# total 7135
# 5529.92

# %%
tt=df[df['Type']==' Tuk-Tuk']['Track ID'].unique()
pedRow=df[df['Type']==' Tuk-Tuk']['Track ID'].count()
df=df[df['Track ID'].isin(tt)]
df=df.sort_values(by=['Track ID','TimeStamp'])
ip_count=len(tt)
dt=0.16
Dx=np.zeros(len(df))
Dy=np.zeros(len(df))
dx=np.nan
dy=np.nan
i=0
while i<len(df):
    if (i==0):
        pass
    elif(df['Track ID'].iloc[i]!=df['Track ID'].iloc[i-1]):
        dx=np.nan
        dy=np.nan
    else:
        dx=df['X'].iloc[i]-df['X'].iloc[i-1]
        dy=df['Y'].iloc[i]-df['Y'].iloc[i-1]

    Dx[i]=(dx)
    Dy[i]=(dy)
    i+=1

df['dx']=Dx
df['dy']=Dy
df['vx']=df['dx']/dt
df['vy']=df['dy']/dt
df.to_csv(r"D:\T\test_codeEVT\nd2/tt.csv")

# %%
df=pd.read_csv(r"D:\T\test_codeEVT\nd2/tt.csv")
before= df['Type'].count()
tt=df[df['Type']==' Tuk-Tuk']['Track ID'].unique()
counter=0
fp=0
t=14
t2=30
print(f'total Tuk-Tuk : {len(tt)}')
plt.figure(figsize=(15,5))

for i in tt:
    y=df[df['Track ID']==i]['vy']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
    if(y.mean()<t):
        counter+=1
    if (y.max()>t2):
        fp+=1

plt.title(f'{counter} is less than <{t} m/s> --{round(counter*100/len(tt),2)}%')
print(f'total fast tt (max) > {t2} m/s : {fp}')
# Out:
# total Tuk-Tuk : 1740
# total fast tt (max) > 30 m/s : 91

# %%
dt=0.16
def kalman_1d(track_series, c=0.01, r=0.005):
    if np.isnan(track_series.iloc[0]):
        track_series = track_series.fillna(method='ffill').fillna(method='bfill')
    n = len(track_series)
    if n == 0:
        return np.array([])

    x = np.zeros(n)
    p = np.zeros(n)
    x_minus = np.zeros(n)
    p_minus = np.zeros(n)
    k_gain = np.zeros(n)

    x[0] = track_series.iloc[0]
    p[0] = 1

    for i in range(1, n):
        x_minus[i] = x[i - 1]
        p_minus[i] = p[i - 1] + c
        k_gain[i] = p_minus[i] / (p_minus[i] + r)
        x[i] = x_minus[i] + k_gain[i] * (track_series.iloc[i] - x_minus[i])
        p[i] = (1 - k_gain[i]) * p_minus[i]

    return x

c=0.001
r=0.0001
for m in tt:
    track_df = df[df['Track ID'] == m]
    if track_df.empty:
        continue  # skip if no data
    nom = len(track_df)
    vy_s = kalman_1d(track_df['vy'], c=c, r=r)
    dy_s = dt * vy_s
    y_s = np.zeros(nom)
    y_s[0] = track_df['Y'].iloc[0]
    for i in range(1, nom):
        y_s[i] = y_s[i - 1] + dy_s[i]

    df.loc[track_df.index, 'vy_smooth'] = vy_s
    df.loc[track_df.index, 'dy_smooth'] = dy_s
    df.loc[track_df.index, 'y_smooth'] = y_s
for m in tt:
    track_df = df[df['Track ID'] == m]
    if track_df.empty:
        continue  # skip if no data
    nom = len(track_df)

    vx_s = kalman_1d(track_df['vx'], c=c, r=r)
    dx_s = dt * vx_s

    x_s = np.zeros(nom)
    x_s[0] = track_df['X'].iloc[0]
    for i in range(1, nom):
        x_s[i] = x_s[i - 1] + dx_s[i]

    df.loc[track_df.index, 'vx_smooth'] = vx_s
    df.loc[track_df.index, 'dx_smooth'] = dx_s
    df.loc[track_df.index, 'x_smooth'] = x_s
# Out:
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# ...
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_25660\101284630.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')

# %%
dt=0.16
Dvx=np.zeros(len(df))
Dvy=np.zeros(len(df))
dvx=np.nan
dvy=np.nan
i=0
while i<len(df):
    if (i==0):
        pass
    elif(df['Track ID'].iloc[i]!=df['Track ID'].iloc[i-1]):
        dvx=np.nan
        dvy=np.nan
    else:
        dvx=df['vx_smooth'].iloc[i]-df['vx_smooth'].iloc[i-1]
        dvy=df['vy_smooth'].iloc[i]-df['vy_smooth'].iloc[i-1]

    Dvx[i]=(dvx)
    Dvy[i]=(dvy)
    i+=1

df['dvx']=Dvx
df['dvy']=Dvy
df['ax']=df['dvx']/dt
df['ay']=df['dvy']/dt
# df.to_csv(r"D:\T\test_codeEVT\nd2")
HA=np.zeros(len(df))
ha=np.nan

i=0
while i<len(df):
    if (i==0):
        pass
    elif(df['Track ID'].iloc[i]!=df['Track ID'].iloc[i-1]):
        ha=np.nan
    else:
        ha=np.degrees(np.arctan2(df['vy_smooth'].iloc[i], df['vx_smooth'].iloc[i])) % 360


    HA[i]=(ha)
    i+=1

df['HA']=HA

# df.to_csv(r"D:\T\test_codeEVT\nd2")

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Track ID', 'TimeStamp', 'Type', 'X', 'Y', 'dx', 'dy',
#        'vx', 'vy', 'vy_smooth', 'dy_smooth', 'y_smooth', 'vx_smooth',
#        'dx_smooth', 'x_smooth', 'dvx', 'dvy', 'ax', 'ay', 'HA'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
for i in tt:
    y=df[df['Track ID']==i]['vx_smooth']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
plt.ylim(-50,50)
plt.show()

# %%
df = df[df['vx_smooth'].abs() <= t2]
df = df[df['vy_smooth'].abs() <= t2]
after= df['Track ID'].count()
print(f'% loss of data {100- after*100/before}')


counter=0
fp=0
t=14
t2=30


plt.figure(figsize=(15,5))
print(f'total tt : {len(tt)}')
for i in tt:
    y=df[df['Track ID']==i]['vy_smooth']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
    if(y.mean()<t):
        counter+=1
    if (y.max()>t2):
        fp+=1
plt.ylim(-50,50)
plt.title(f'{counter} is less than <{t} m/s> --{round(counter*100/len(tt),2)}%')
print(before)
print(after)
# Out:
# % loss of data 0.9147109300556338
# total tt : 1740
# 385149
# 381626

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Track ID', 'TimeStamp', 'Type', 'X', 'Y', 'dx', 'dy',
#        'vx', 'vy', 'vy_smooth', 'dy_smooth', 'y_smooth', 'vx_smooth',
#        'dx_smooth', 'x_smooth', 'dvx', 'dvy', 'ax', 'ay', 'HA'],
#       dtype='object')

# %%
counter=0
fp=0
t=14
t2=30

plt.figure(figsize=(15,5))
print(f'total tt : {len(tt)}')
for i in tt:
    y=df[df['Track ID']==i]['vy_smooth']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
    if(y.mean()<t):
        counter+=1
    if (y.max()>t2):
        fp+=1
plt.ylim(-50,50)
print(f'{counter} TukTuk are having <v> less than {t} m/s --{round(counter*100/len(tt),2)}%')
plt.title(f'{counter} TukTuk are having <v> less than {t} m/s --{round(counter*100/len(tt),2)}%')
# Out:
# total tt : 1740
# 1738 TukTuk are having <v> less than 14 m/s --99.89%
# Text(0.5, 1.0, '1738 TukTuk are having <v> less than 14 m/s --99.89%')

# %%
# df.to_csv(r"C:\Users\Tusha\Visual Studio Codes\test_codeEVT\smoothen_data/tuktuk_smooth.csv")

# %%
import pandas as pd
# df=pd.read_csv(r"C:\Users\Tusha\Visual Studio Codes\test_codeEVT\smoothen_data/tuktuk_smooth.csv")
df['speed']=((df['vx_smooth']**2+df['vy_smooth']**2)**0.5)
t=22
f=df[df['speed']>t]
len(f)
len(df)
print(f'speed greater than {t}m/s ={len(f)} -- {len(f)/len(df)} %')
# Out:
# speed greater than 22m/s =2578 -- 0.006755304932053896 %

# %%
df=df[df['speed']<t]

df=df[['Track ID', 'TimeStamp', 'Type', 'X', 'Y', 'dx', 'dy',
       'vx', 'vy', 'vy_smooth', 'dy_smooth', 'y_smooth', 'vx_smooth',
       'dx_smooth', 'x_smooth', 'dvx', 'dvy', 'ax', 'ay', 'HA']]
df.to_csv(r"D:\T\test_codeEVT\nd/tuktuk_smooth.csv")

# %%
df=pd.read_csv(r"D:\T\test_codeEVT\nd/tuktuk_smooth.csv")

after= len(df)
print(f'% loss of data {100- after*100/before}')
print(before)
print(after)
# Out:
# % loss of data 1.5840622720038198
# 385149
# 379048

# %%
print(df)
# Out:
#         Unnamed: 0  Track ID  TimeStamp      Type          X           Y  \
# 0                0         1       0.00   Tuk-Tuk  778898.05  1435734.56
# 1                1         1       0.16   Tuk-Tuk  778898.05  1435734.56
# 2                2         1       0.32   Tuk-Tuk  778898.05  1435734.56
# 3                3         1       0.48   Tuk-Tuk  778898.05  1435734.57
# 4                4         1       0.64   Tuk-Tuk  778898.05  1435734.57
# ...            ...       ...        ...       ...        ...         ...
# 379043      385144     16163    5529.20   Tuk-Tuk  778894.60  1435736.81
# 379044      385145     16163    5529.36   Tuk-Tuk  778894.56  1435736.84
# 379045      385146     16163    5529.52   Tuk-Tuk  778894.55  1435736.85
# 379046      385147     16163    5529.68   Tuk-Tuk  778894.55  1435736.84
# 379047      385148     16163    5529.84   Tuk-Tuk  778894.56  1435736.84
#
#           dx    dy      vx      vy  ...  dy_smooth      y_smooth  vx_smooth  \
# 0        NaN   NaN     NaN     NaN  ...   0.000000  1.435735e+06   0.000000
# 1       0.00  0.00  0.0000  0.0000  ...   0.000000  1.435735e+06   0.000000
# 2       0.00  0.00  0.0000  0.0000  ...   0.000000  1.435735e+06   0.000000
# 3       0.00  0.01  0.0000  0.0625  ...   0.009161  1.435735e+06   0.000000
# 4       0.00  0.00  0.0000  0.0000  ...   0.000769  1.435735e+06   0.000000
# ...      ...   ...     ...     ...  ...        ...           ...        ...
# 379043 -0.05  0.04 -0.3125  0.2500  ...   0.040846  1.435737e+06  -0.317788
# 379044 -0.04  0.03 -0.2500  0.1875  ...   0.030910  1.435737e+06  -0.255689
# 379045 -0.01  0.01 -0.0625  0.0625  ...   0.011755  1.435737e+06  -0.078712
# 379046  0.00 -0.01  0.0000 -0.0625  ...  -0.008174  1.435737e+06  -0.006606
# 379047  0.01  0.00  0.0625  0.0000  ...  -0.000686  1.435737e+06   0.056701
#
#         dx_smooth       x_smooth       dvx       dvy        ax        ay  \
# 0        0.000000  778898.050000       NaN       NaN       NaN       NaN
# 1        0.000000  778898.050000  0.000000  0.000000  0.000000  0.000000
# 2        0.000000  778898.050000  0.000000  0.000000  0.000000  0.000000
# 3        0.000000  778898.050000  0.000000  0.057255  0.000000  0.357845
# 4        0.000000  778898.050000  0.000000 -0.052450  0.000000 -0.327815
# ...           ...            ...       ...       ...       ...       ...
# 379043  -0.050846  778894.598258  0.057729 -0.057692  0.360806 -0.360577
# 379044  -0.040910  778894.557348  0.062100 -0.062097  0.388123 -0.388103
# 379045  -0.012594  778894.544754  0.176976 -0.119721  1.106102 -0.748257
# 379046  -0.001057  778894.543697  0.072107 -0.124557  0.450668 -0.778481
# 379047   0.009072  778894.552769  0.063306  0.046802  0.395664  0.292513
#
#                 HA
# 0              NaN
# 1         0.000000
# 2         0.000000
# 3        90.000000
# 4        90.000000
# ...            ...
# 379043  141.224471
# 379044  142.926723
# 379045  136.973977
# 379046  262.632882
# 379047  355.675779
#
# [379048 rows x 21 columns]

# %%
import pandas as pd
df=pd.read_csv(r"D:\T\test_codeEVT\nd\tuktuk_smooth.csv")
df['speed']=((df['vx_smooth']**2+df['vy_smooth']**2)**0.5)
print(df['speed'].mean())
# Out:
# 1.5021237460069272
