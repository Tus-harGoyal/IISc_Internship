# %%
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
import math
import pandas as pd

# %%
df=pd.read_csv(r"D:\T\test_codeEVT\dataset\Majestic.csv")
df=df[['Track ID','TimeStamp','Type','X','Y']].dropna()
df['Track ID'] = df['Track ID'].astype(int)
df=df[df['Track ID']>=1]
df['Track ID'] = df['Track ID'].sort_values()
unique_tracks_per_type = df.groupby('Type')['Track ID'].nunique()
print(unique_tracks_per_type)
print(f'total {sum(unique_tracks_per_type)}')
print(df['TimeStamp'].max())
unique_tracks_per_type.to_csv(r"D:\T\test_codeEVT\unique_tracks_per_type.csv")
# Out:
# Type
# Bicycle           1
# Bus              61
# Car            1040
# Light Truck     203
# Motorcycle     3011
# Pedestrian     1069
# Tractor           1
# Tuk-Tuk        1740
# Van               9
# Name: Track ID, dtype: int64
# total 7135
# 5529.92

# %%
bus=df[df['Type']==' Bus']['Track ID'].unique()
pedRow=df[df['Type']==' Bus']['Track ID'].count()
df=df[df['Track ID'].isin(bus)]
df=df.sort_values(by=['Track ID','TimeStamp'])
ip_count=len(bus)
dt=0.16
Dx=np.zeros(len(df))
Dy=np.zeros(len(df))
dx=np.nan
dy=np.nan
i=0
while i<len(df):
    if (i==0):
        pass
    elif(df['Track ID'].iloc[i]!=df['Track ID'].iloc[i-1]):
        dx=np.nan
        dy=np.nan
    else:
        dx=df['X'].iloc[i]-df['X'].iloc[i-1]
        dy=df['Y'].iloc[i]-df['Y'].iloc[i-1]

    Dx[i]=(dx)
    Dy[i]=(dy)
    i+=1

df['dx']=Dx
df['dy']=Dy
df['vx']=df['dx']/dt
df['vy']=df['dy']/dt
df.to_csv(r"C:\Users\Tusha\Visual Studio Codes\test_codeEVT\Temp/bus.csv")

# %%
df=pd.read_csv(r"D:\T\test_codeEVT\Temp/bus.csv")
before= len(df)
bus=df[df['Type']==' Bus']['Track ID'].unique()
counter=0
fp=0
t=14
t2=22
print(f'total Bus : {len(bus)}')
for i in bus:
    y=df[df['Track ID']==i]['vx']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
    if(y.mean()<t):
        counter+=1
    if (y.max()>t2):
        fp+=1

plt.title(f'{counter} is less than <{t} m/s> --{round(counter*100/len(bus),2)}%')
print(f'total fast bus (max) > {t2} m/s : {fp}')
print(before)
# Out:
# total Bus : 61
# total fast bus (max) > 22 m/s : 50
# 16187

# %%
dt=0.16
def kalman_1d(track_series, c=0.01, r=0.005):
    if np.isnan(track_series.iloc[0]):
        track_series = track_series.fillna(method='ffill').fillna(method='bfill')
    n = len(track_series)
    if n == 0:
        return np.array([])

    x = np.zeros(n)
    p = np.zeros(n)
    x_minus = np.zeros(n)
    p_minus = np.zeros(n)
    k_gain = np.zeros(n)

    x[0] = track_series.iloc[0]
    p[0] = 1

    for i in range(1, n):
        x_minus[i] = x[i - 1]
        p_minus[i] = p[i - 1] + c
        k_gain[i] = p_minus[i] / (p_minus[i] + r)
        x[i] = x_minus[i] + k_gain[i] * (track_series.iloc[i] - x_minus[i])
        p[i] = (1 - k_gain[i]) * p_minus[i]

    return x

c=0.001
r=0.001
for m in bus:
    track_df = df[df['Track ID'] == m]
    if track_df.empty:
        continue  # skip if no data
    nom = len(track_df)
    vy_s = kalman_1d(track_df['vy'], c=c, r=r)
    dy_s = dt * vy_s
    y_s = np.zeros(nom)
    y_s[0] = track_df['Y'].iloc[0]
    for i in range(1, nom):
        y_s[i] = y_s[i - 1] + dy_s[i]

    df.loc[track_df.index, 'vy_smooth'] = vy_s
    df.loc[track_df.index, 'dy_smooth'] = dy_s
    df.loc[track_df.index, 'y_smooth'] = y_s
for m in bus:
    track_df = df[df['Track ID'] == m]
    if track_df.empty:
        continue  # skip if no data
    nom = len(track_df)

    vx_s = kalman_1d(track_df['vx'], c=c, r=r)
    dx_s = dt * vx_s

    x_s = np.zeros(nom)
    x_s[0] = track_df['X'].iloc[0]
    for i in range(1, nom):
        x_s[i] = x_s[i - 1] + dx_s[i]

    df.loc[track_df.index, 'vx_smooth'] = vx_s
    df.loc[track_df.index, 'dx_smooth'] = dx_s
    df.loc[track_df.index, 'x_smooth'] = x_s
# Out:
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')
# C:\Users\IST LAB 2\AppData\Local\Temp\ipykernel_27392\1756837717.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   track_series = track_series.fillna(method='ffill').fillna(method='bfill')

# %%
dt=0.16
Dvx=np.zeros(len(df))
Dvy=np.zeros(len(df))
dvx=np.nan
dvy=np.nan
i=0
while i<len(df):
    if (i==0):
        pass
    elif(df['Track ID'].iloc[i]!=df['Track ID'].iloc[i-1]):
        dvx=np.nan
        dvy=np.nan
    else:
        dvx=df['vx_smooth'].iloc[i]-df['vx_smooth'].iloc[i-1]
        dvy=df['vy_smooth'].iloc[i]-df['vy_smooth'].iloc[i-1]

    Dvx[i]=(dvx)
    Dvy[i]=(dvy)
    i+=1

df['dvx']=Dvx
df['dvy']=Dvy
df['ax']=df['dvx']/dt
df['ay']=df['dvy']/dt
# df.to_csv(r"D:\T\test_codeEVT\nd2")
HA=np.zeros(len(df))
ha=np.nan

i=0
while i<len(df):
    if (i==0):
        pass
    elif(df['Track ID'].iloc[i]!=df['Track ID'].iloc[i-1]):
        ha=np.nan
    else:
        ha=np.degrees(np.arctan2(df['vy_smooth'].iloc[i], df['vx_smooth'].iloc[i])) % 360


    HA[i]=(ha)
    i+=1

df['HA']=HA

# df.to_csv(r"D:\T\test_codeEVT\nd2")

# %%
df.head()
# Out:
#    Unnamed: 0  Track ID  TimeStamp  Type          X           Y    dx    dy  \
# 0       25712       439     157.24   Bus  778745.11  1435894.72   NaN   NaN
# 1       25713       439     157.40   Bus  778751.78  1435888.05  6.67 -6.67
# 2       25714       439     157.56   Bus  778757.85  1435881.99  6.07 -6.06
# 3       25715       439     157.72   Bus  778762.81  1435877.03  4.96 -4.96
# 4       25716       439     157.88   Bus  778766.56  1435873.28  3.75 -3.75
#
#         vx       vy  ...  dy_smooth      y_smooth  vx_smooth  dx_smooth  \
# 0      NaN      NaN  ...  -6.670000  1.435895e+06  41.687500   6.670000
# 1  41.6875 -41.6875  ...  -6.670000  1.435888e+06  41.687500   6.670000
# 2  37.9375 -37.8750  ...  -6.263401  1.435882e+06  39.187916   6.270067
# 3  31.0000 -31.0000  ...  -5.448796  1.435876e+06  34.070596   5.451295
# 4  23.4375 -23.4375  ...  -4.397164  1.435872e+06  27.488227   4.398116
#
#         x_smooth       dvx       dvy         ax         ay          HA
# 0  778745.110000       NaN       NaN        NaN        NaN         NaN
# 1  778751.780000  0.000000  0.000000   0.000000   0.000000  315.000000
# 2  778758.050067 -2.499584  2.541244 -15.622400  15.882773  315.030471
# 3  778763.501362 -5.117320  5.091283 -31.983248  31.820519  315.013139
# 4  778767.899478 -6.582369  6.572697 -41.139805  41.079359  315.006203
#
# [5 rows x 21 columns]

# %%
df = df[df['vx_smooth'].abs() <= t2]
df = df[df['vy_smooth'].abs() <= t2]
after= len(df)
print(f'% loss of data {100- after*100/before}')

counter=0
fp=0
t=14
t2=22


plt.figure(figsize=(15,5))
print(f'total bus : {len(bus)}')
for i in bus:
    y=df[df['Track ID']==i]['vx_smooth']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
    if(y.mean()<t):
        counter+=1
    if (y.max()>t2):
        fp+=1
plt.ylim(-50,50)
plt.title(f'{counter} is less than <{t} m/s> --{round(counter*100/len(bus),2)}%')
print(before)
print(after)
# Out:
# % loss of data 3.9723234694507994
# total bus : 61
# 16187
# 15544

# %%
counter=0
fp=0
t=14
t2=30

plt.figure(figsize=(15,5))
print(f'total bus : {len(bus)}')
for i in bus:
    y=df[df['Track ID']==i]['vx_smooth']
    x=np.linspace(0,10,len(y))
    plt.plot(x,y)
    if(y.mean()<t):
        counter+=1
    if (y.max()>t2):
        fp+=1
plt.ylim(-25,25)
plt.title(f'{counter} is less than <{t} m/s> --{round(counter*100/len(bus),2)}%')
# Out:
# total bus : 61
# Text(0.5, 1.0, '61 is less than <14 m/s> --100.0%')

# %%
# df.to_csv(r"C:\Users\Tusha\Visual Studio Codes\test_codeEVT\smoothen_data/bus_smooth.csv")

# %%
# df.to_csv(r"C:\Users\Tusha\Visual Studio Codes\test_codeEVT\smoothen_data/car_smooth.csv")
import pandas as pd
# df=pd.read_csv(r"C:\Users\Tusha\Visual Studio Codes\test_codeEVT\smoothen_data/bus_smooth.csv")
df['speed']=((df['vx_smooth']**2+df['vy_smooth']**2)**0.5)
t=11
f=df[df['speed']>t]
len(f)
len(df)
print(f'speed greater than {t}m/s ={len(f)} -- {len(f)/before} %')
print(len(f))
print(before)
# Out:
# speed greater than 11m/s =619 -- 0.03824056341508618 %
# 619
# 16187

# %%
df=df[df['speed']<=t]
print(len(df))
df=df[['Track ID', 'TimeStamp', 'Type', 'X', 'Y', 'dx', 'dy',
       'vx', 'vy', 'vy_smooth', 'dy_smooth', 'y_smooth', 'vx_smooth',
       'dx_smooth', 'x_smooth', 'dvx', 'dvy', 'ax', 'ay', 'HA']]
df.to_csv(r"D:\T\test_codeEVT\nd/bus_smooth.csv")
# Out:
# 14925

# %%
df=pd.read_csv(r"D:\T\test_codeEVT\nd/bus_smooth.csv")
# print(before)
after= len(df)
print(f'% loss of data {100- after*100/before}')
# Out:
# % loss of data 7.796379810959408
